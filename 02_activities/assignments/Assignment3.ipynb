# %%
import matplotlib.pyplot as plt

# Data from your Excel chart
regions = [
    "NORTHERN ONTARIO",
    "MUSKOKA, PARRY SOUND AND ALGONQUIN PARK",
    "HALIBURTON HIGHLANDS TO THE OTTAWA VALLEY",
    "OTTAWA AND COUNTRYSIDE",
    "SOUTHEASTERN ONTARIO",
    "KAWARTHAS NORTHUMBERLAND",
    "BRUCE PENINSULA, SOUTHERN GEORGIAN BAY AND LAKE SIMCOE",
    "YORK, DURHAM, HILLS OF HEADWATERS",
    "GREATER TORONTO AREA",
    "HURON, PERTH, WATERLOO, WELLINGTON",
    "HAMILTON, HALTON, BRANT",
    "NIAGARA CANADA",
    "SOUTHWEST ONTARIO"
]

adr_values = [
    187.8618845,
    314.4011739,
    167.965721,
    204.2060806,
    209.1309198,
    169.4194867,
    198.9776216,
    208.5054942,
    277.2582589,
    184.5419641,
    171.5213955,
    287.0656669,
    153.4691568
]

# Create line graph
plt.figure(figsize=(12, 6))
plt.plot(regions, adr_values, marker='o', linestyle='-', color='steelblue')

# Add titles and labels
plt.title("Average Daily Rate (ADR) - August 2025", fontsize=14, weight='bold')
plt.xlabel("Region", fontsize=12)
plt.ylabel("Average Daily Rate ($)", fontsize=12)

# Rotate x labels for readability
plt.xticks(rotation=75, ha='right')

# Add grid and tighten layout
plt.grid(True, linestyle='--', alpha=0.6)
plt.tight_layout()

# Show graph
plt.show()
